# %%
import requests
from bs4 import BeautifulSoup
import re
import urllib.parse
import pandas as pd
import re

pd.set_option('display.max_colwidth', None)

def get_soup(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    return soup

def get_links(soup, base_url):
    links = []
    for link in soup.find_all('a', href=True):
        url = link['href']
        # Resolve relative links
        url = urllib.parse.urljoin(base_url, url)
        # Only add links that start with the base URL
        if url.startswith(base_url) and url not in links:
            links.append(url)
    return links

def get_text(soup):
    # Ignore non-text content by only extracting text within <p> tags
    text = '\n'.join([paragraph.get_text() for paragraph in soup.find_all('p')])
    return text

def get_tables(soup):
    tables = []
    for table in soup.find_all('table'):
        table_text = '\n'.join([str(row) for row in table.find_all('tr')])
        tables.append(table_text)
    return '\n'.join(tables)

def get_title(soup):
    title = soup.find('title').get_text()
    return title

def scrape_website(base_url):
    visited = set()
    to_visit = [(base_url, None)]  # (url, parent_url)
    data = []

    while to_visit:
        url, parent_url = to_visit.pop()
        if url in visited:
            continue
        visited.add(url)

        soup = get_soup(url)

        title = get_title(soup)
        text = get_text(soup)
        tables = get_tables(soup)

        data.append((title, text, tables))

        links = get_links(soup, base_url)
        to_visit.extend((link, url) for link in links if link not in visited)

    df = pd.DataFrame(data, columns=['title', 'text', 'tables'])

    return df

def remove_unwanted_text(df, unwanted_text):
    # Apply the removal to the 'text' column of the DataFrame
    df['text'] = df['text'].apply(lambda x: x.replace(unwanted_text, '', 1) if x.startswith(unwanted_text) else x)
    return df

base_url = "https://www.uscis.gov/working-in-the-united-states"
df = scrape_website(base_url)

unwanted_text = "Official websites use .gov\nA .gov website belongs to an official government organization in the United States.\nSecure .gov websites use HTTPS\nA lock ( A locked padlock  ) or https:// means you've safely connected to the .gov website. Share sensitive information only on official, secure websites.\n"
df = remove_unwanted_text(df, unwanted_text)

# %%
pd.set_option('display.max_colwidth', None)

# %%
df['tables'][4:5]
# Out:
# 4    <tr><th scope="col">To establish…</th>\n<th scope="col">You can submit…</th>\n</tr>\n<tr><td>\n<p>Your E-3, H-1B, H-1B1, O-1, or L-1 nonimmigrant status</p>\n</td>\n<td>\n<ul><li>A copy of your current Form I-797 approval notice for Form I-129, Petition for a Nonimmigrant Worker; or</li>\n<li>A copy of Form I-94, Arrival/Departure Record, showing your admission as an E-3, H-1B, H-1B1, O-1, or L-1 nonimmigrant.</li>\n</ul><p>Note: If you are filing for a (c)(35) or (c)(36) renewal EAD, you do not need to be in a valid nonimmigrant status at the time you file your renewal application.  Instead, your EAD must be valid at the time you file your EAD renewal application.</p>\n</td>\n</tr>\n<tr><td>\n<p>Your identity</p>\n</td>\n<td>\n<p>A government-issued identification document with photo, such as:</p>\n<ul><li>A copy of the biometric page of your passport;</li>\n<li>A birth certificate with photo ID;</li>\n<li>A visa issued by a foreign consulate; or</li>\n<li>A national identity document with photo.</li>\n</ul></td>\n</tr>\n<tr><td>\n<p>That an immigrant visa is not authorized for issuance to you based on your priority date, preference category, and country of chargeability according to the Final Action Date in effect on the date you file Form I-765</p>\n</td>\n<td>\n<ul><li>A copy of an approval notice for Form I-140 filed for you; or</li>\n<li>Other evidence showing the priority date assigned to an approved Form I-140 filed for you.</li>\n</ul></td>\n</tr>\n<tr><td>\n<p>That compelling circumstances exist that justify USCIS using its discretion to issue you an independent grant of employment authorization (see our <a data-entity-substitution="canonical" data-entity-type="node" data-entity-uuid="ff64aa90-1880-4e85-a763-693dff0398da" href="/policy-manual">Policy Manual</a> for more details)</p>\n</td>\n<td>\n<ul><li>Medical documentation to show you or your dependent are facing a serious illness or disability;</li>\n<li>Evidence that your employer has retaliated against you;</li>\n<li>Evidence of other substantial harm to you or your dependents, which could include your priority date, school or higher education enrollment records, mortgage records, long-term lease records, or documentation regarding home country conditions, as applicable;</li>\n<li>Evidence of significant disruption to the employer; or</li>\n<li>Other evidence that demonstrates you are experiencing compelling circumstances.</li>\n</ul></td>\n</tr>\n<tr><td>That you have not been convicted of a felony, or two or more misdemeanors</td>\n<td>\n<ul><li>Certified copies of all arrest reports, court dispositions, sentencing documents, and any other relevant documents.</li>\n</ul></td>\n</tr>\n<tr><th scope="col">To establish…</th>\n<th scope="col">You can submit…</th>\n</tr>\n<tr><td>\n<p>Your nonimmigrant status at the time the principal beneficiary applies for (c)(35) employment authorization</p>\n</td>\n<td>\n<ul><li>A copy of your current Form I-797 approval notice for Form I-129, Petition for a Nonimmigrant Worker, or a copy of your current Form I-797 approval notice for Form I-539, Application to Extend/Change Nonimmigrant Status; or</li>\n<li>A copy of Form I-94, Arrival/Departure Record, showing your admission as a nonimmigrant.</li>\n</ul><p>Note: If you are filing for a (c)(36) renewal EAD, you do not need to be in a valid nonimmigrant status at the time you file your renewal application. Instead, your EAD must be valid at the time you file your EAD renewal application.</p>\n</td>\n</tr>\n<tr><td>\n<p>Your identity</p>\n</td>\n<td>\n<p>A government-issued identification document with photo, such as:</p>\n<ul><li>A copy of the biometric page of your passport;</li>\n<li>A birth certificate with photo ID;</li>\n<li>A visa issued by a foreign consulate; or</li>\n<li>A national identity document with photo.</li>\n</ul></td>\n</tr>\n<tr><td>\n<p>That the principal beneficiary has an approved Form I-765 under (c)(35)</p>\n</td>\n<td>\n<ul><li>A copy of an appr ...
# Name: tables, dtype: object

# %%
def preprocess_text(text):
    # Remove reference tags (e.g., [1], [2], etc.)
    text = re.sub(r'\[\d+\]', '', text)
    # Remove excessive whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def split_into_sections(text, max_length=1600):
    # Split the text into paragraphs
    paragraphs = text.split('\n')
    sections = []
    section = ''
    for paragraph in paragraphs:
        # If adding the next paragraph doesn't exceed the maximum length,
        # add the paragraph to the current section
        if len(section) + len(paragraph) < max_length:
            section += paragraph
        else:
            # If it does, start a new section
            sections.append(section)
            section = paragraph
    # Don't forget to add the last section
    if section:
        sections.append(section)
    return sections

def post_process(df):
    # Discard less relevant-looking sections like "External Links" and "Footnotes"
    df = df[~df['title'].str.contains('External Links|Footnotes', case=False)]
    # Clean up the text
    df['text'] = df['text'].apply(preprocess_text)
    # Split each article into sections
    df['sections'] = df['text'].apply(split_into_sections)
    # Prepend titles to each section's text
    df['sections'] = df.apply(lambda row: [f"{row['title']}\n{section}" for section in row['sections']], axis=1)
    # Unroll the sections into separate rows
    df = df.explode('sections')
    df['text'] = df['sections']
    df.drop(columns=['sections'], inplace=True)
    return df

df = post_process(df)

# %%
df.to_csv("visa_embeddings.csv", index=False)

# %%
df.head(10)
# Out:
#                                                title  \
# 0               Working in the United States | USCIS
# 0               Working in the United States | USCIS
# 1                  Petition Process Overview | USCIS
# 2                        Report Labor Abuses | USCIS
# 2                        Report Labor Abuses | USCIS
# 3  Options for Nonimmigrant Workers Following Ter...
# 3  Options for Nonimmigrant Workers Following Ter...
# 4  Employment Authorization in Compelling Circums...
# 4  Employment Authorization in Compelling Circums...
# 5  Validation Instrument for Business Enterprises...
#
#                                                  url  \
# 0  https://www.uscis.gov/working-in-the-united-st...
# 0  https://www.uscis.gov/working-in-the-united-st...
# 1  https://www.uscis.gov/working-in-the-united-st...
# 2  https://www.uscis.gov/working-in-the-united-st...
# 2  https://www.uscis.gov/working-in-the-united-st...
# 3  https://www.uscis.gov/working-in-the-united-st...
# 3  https://www.uscis.gov/working-in-the-united-st...
# 4  https://www.uscis.gov/working-in-the-united-st...
# 4  https://www.uscis.gov/working-in-the-united-st...
# 5  https://www.uscis.gov/working-in-the-united-st...
#
#                                           parent_url  \
# 0                                               None
# 0                                               None
# 1  https://www.uscis.gov/working-in-the-united-st...
# 2  https://www.uscis.gov/working-in-the-united-st...
# 2  https://www.uscis.gov/working-in-the-united-st...
# 3  https://www.uscis.gov/working-in-the-united-st...
# 3  https://www.uscis.gov/working-in-the-united-st...
# 4  https://www.uscis.gov/working-in-the-united-st...
# 4  https://www.uscis.gov/working-in-the-united-st...
# 5  https://www.uscis.gov/working-in-the-united-st...
#
#                                                 text  \
# 0             Working in the United States | USCIS\n
# 0  Working in the United States | USCIS\nMany non...
# 1  Petition Process Overview | USCIS\nIf you woul...
# 2                      Report Labor Abuses | USCIS\n
# 2  Report Labor Abuses | USCIS\nWe are committed ...
# 3  Options for Nonimmigrant Workers Following Ter...
# 3  Options for Nonimmigrant Workers Following Ter...
# 4  Employment Authorization in Compelling Circums...
# 4  Employment Authorization in Compelling Circums...
# 5  Validation Instrument for Business Enterprises...
#
#                                               tables
# 0
# 0
# 1
# 2
# 2
# 3
# 3
# 4  <tr><th scope="col">To establish…</th>\n<th sc...
# 4  <tr><th scope="col">To establish…</th>\n<th sc...
# 5

# %%
df.shape
# Out:
# (173, 5)

# %%
df.to_csv("visa_embeddings.csv")

# %%
df['title'].unique()
# Out:
# array(['Working in the United States | USCIS',
#        'Petition Process Overview | USCIS', 'Report Labor Abuses | USCIS',
#        'Options for Nonimmigrant Workers Following Termination of Employment | USCIS',
#        'Employment Authorization in Compelling Circumstances | USCIS',
#        'Validation Instrument for Business Enterprises (VIBE) Program | USCIS',
#        'VIBE Questions and Answers | USCIS',
#        'Employment Authorization | USCIS', 'Employer Information | USCIS',
#        'DHS Support of the Enforcement of Labor and Employment Laws | USCIS',
#        'Information for Employers and Employees | USCIS',
#        'WB Temporary Business Visitor under Visa Waiver Program | USCIS',
#        'GB Temporary Visitor to Guam | USCIS',
#        'B-1 Temporary Business Visitor | USCIS',
#        'Temporary Visitors for Business | USCIS',
#        'Students and Employment | USCIS',
#        'Changing to a Nonimmigrant F or M Student Status | USCIS',
#        'Exchange Visitors | USCIS', 'Conrad 30 Waiver Program | USCIS',
#        'Students and Exchange Visitors | USCIS',
#        'Nonimmigrant or Parole Pathways for Entrepreneur Employment in the United States | USCIS',
#        'Optional Practical Training (OPT) for F-1 Students | USCIS',
#        'Immigrant Pathways for Entrepreneur Employment in the United States | USCIS',
#        'Options for Noncitizen Entrepreneurs to Work in the United States | USCIS',
#        'Nonimmigrant Pathways for STEM Employment in the United States | USCIS',
#        'Optional Practical Training Extension for STEM Students (STEM OPT) | USCIS',
#        'Immigrant Pathways for STEM Employment in the United States | USCIS',
#        'Options for Noncitizen STEM Professionals to Work in the United States | USCIS',
#        'EB-5 Immigrant Investor Process | USCIS',
#        'About the EB-5 Visa Classification | USCIS',
#        'EB-5 Immigrant Investor Regional Centers | USCIS',
#        'Regional Center Terminations | USCIS',
#        'Approved EB-5 Immigrant Investor Regional Centers | USCIS',
#        'EB-5 Immigrant Investor Program | USCIS', 'EB-5 Support | USCIS',
#        'EB-5 Filing Tips | USCIS',
#        'Special Immigrant Religious Workers | USCIS',
#        'Special Immigrant Juvenile (SIJ) Frequently Asked Questions | USCIS',
#        'Employment-Based Immigration: Fourth Preference EB-4 | USCIS',
#        'Employment-Based Immigration: Third Preference EB-3 | USCIS',
#        'Health Care Worker Certification | USCIS',
#        'Employment-Based Immigration: Second Preference EB-2 | USCIS',
#        'Employment-Based Immigration: First Preference EB-1 | USCIS',
#        'Permanent Workers | USCIS', 'TN NAFTA Professionals | USCIS',
#        'R-1 Nonimmigrant Religious Workers | USCIS',
#        'Q Cultural Exchange | USCIS',
#        'P-3 Artist or Entertainer Coming to Be Part of a Culturally Unique Program | USCIS',
#        'Address Index for I-129 O and P Consultation Letters | USCIS',
#        'P-2 Individual Performer or Part of a Group Entering to Perform Under a Reciprocal Exchange Program | USCIS',
#        'P-1B A Member of an Internationally Recognized Entertainment Group | USCIS',
#        'P-1A Athlete | USCIS',
#        'O Nonimmigrant Classifications: Question and Answers | USCIS',
#        'O-1 Visa: Individuals with Extraordinary Ability or Achievement | USCIS',
#        'Frequently Asked Questions about Part 6 of Form I-129, Petition for a Nonimmigrant Worker | USCIS',
#        'L-1B Intracompany Transferee Specialized Knowledge | USCIS',
#        'Filing Multiple L-1 Intracompany Transferee Petitions Related to the Same Project | USCIS',
#        'L-1A Intracompany Transferee Executive or Manager | USCIS',
#        'I Representatives of Foreign Media | USCIS',
#        'H-3 Nonimmigrant Trainee or Special Education Exchange Visitor | USCIS',
#        'H-2B Temporary Non-Agricultural Workers | USCIS',
#        'Guidance on “Temporary Need” in H-2B Petitions | USCIS',
#        'H-2A Temporary Agricultural Workers | USCIS',
#        'Calculating Interrupted Stays for the H-2 Classifications | USCIS',
#        'Employment Authorization for Certain H-4 Dependent Spouses | USCIS',
#        'Fee Increase for Certain H-1B and L-1 Petitions (Public Law 114-113) | USCIS',
#        'Extension of Post Completion Optional Practical Training (OPT) and F-1 Status for Eligible Students under the H-1B Cap-Gap Regulations | USCIS',
#        'H-1B Electronic Registration Process | USCIS',
#        'H-1B Cap Season | USCIS',
#        'H-1B Specialty Occupations, DOD Cooperative Research and Development Project Workers, and Fashion Models | USCIS',
#        'How USCIS Determines Same or Similar Occupational Classifications for Job Portability Under AC21 | USCIS',
#        'E-3 Specialty Occupation Workers from Australia | USCIS',
#        'E-2 Treaty Investors | USCIS',
#        'E-2 Visa: CNMI-Only Investor | USCIS',
#        'E-1 Treaty Traders | USCIS',
#        'CW-1: CNMI-Only Transitional Worker | USCIS',
#        'Temporary (Nonimmigrant) Workers | USCIS',
#        'International Entrepreneur Rule | USCIS',
#        'Cap Count for H-2B Nonimmigrants | USCIS',
#        'Temporary Increase in H-2B Nonimmigrant Visas for FY 2023 | USCIS',
#        'EB-5 Resources | USCIS',
#        'Suggested Order of Form I-924 Documentation | USCIS',
#        'Suggested Order of Form I-829 Documentation | USCIS',
#        'Suggested Order of Form I-526 Documentation | USCIS',
#        'Questions and Answers: EB-5 Immigrant Investor Program Visa Availability Approach | USCIS',
#        'Questions and Answers: EB-5 Further Deployment | USCIS',
#        'EB-5 Questions and Answers: EB-5 Reform and Integrity Act of 2022 (updated April 2022) | USCIS',
#        "EB-5 What's New | USCIS",
#        'EB-5 Regional Center Compliance Reviews | USCIS'], dtype=object)

# %%
# Out:
# 626
